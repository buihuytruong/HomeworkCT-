# %%
#W3A1
n = int(input())
def d(n):
    a = str(n)
    dao = a[::-1]
    b = int(dao)
    return b 
print(d(n))
# Out:
# 321

# %%
#W3A2
x , y = map(int , input().split())
x = x ^ y
y = x ^ y
x = x ^ y
print(f"x = {x}, y = {y}")
# Out:
# x = 2, y = 1

# %%
#W3A3
n = int(input())
print(n & (n-1) == 0)
# Out:
# False

# %%
#W3A4
m , n = map(int, input().split())
print(m//n)
# Out:
# 0

# %%
#W3A5
m , n = map(int, input().split())
a = m // n
print(a+1)
# Out:
# 1

# %%
#W3A6
a = int(input())
if a%2 == 0:
    print('Even')
else:
    print('Odd')
# Out:
# Even

# %%
#W3A7
a , b = map(int , input().split())
if a < 0 and b <0:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
#W3A8
a , b = input().split()
print(len(a) > len(b))
# Out:
# True

# %%
#W3A9
a , b , c = map(float, input().split())
s = (a+b+c)/2
test = s*(s-a)*(s-b)*(s-c)
if test > 0 and a>0 and b>0 and c>0 :
    print("yes")
else:
    print("no")
# Out:
# no

# %%
#W3A10
a , b , c , d = map(int, input().split())
x =[a , b , c , d]
y = 0
for i in x: 
    if i > y:
        y = i
print(y)
# Out:
# 8

# %%
#W3A11
a , b , c = map(float, input().split())
s = (a+b+c)/2
test = s*(s-a)*(s-b)*(s-c)
if test > 0 and a>0 and b>0 and c>0 :
    if a == b == c:
        print("tam giac deu")
    elif a == b != c or a != b == c or a == c != b:
        print("tam giac can")
    else:
        print(' tam giac thuong hoac vuong')
else:
    print("no")
# Out:
# no

# %%
#W3A12
a = int(input())
if a%4 == 0 and a%100 != 0 or a%400 == 0 :
    print('nam nhuan')
else:
    print('k phai nam nhuan')
# Out:
# k phai nam nhuan

# %%
#W3A13
a = int(input())
if a >= 0 and a <= 50 :
    print(1500*a)
elif a>50 and a <=100:
    print(1500*50+ 2000*(a-50))
elif a> 100 :
    print(1500*50+ 2000*50 + 3000 *(a-100))
# Out:
# 1500

# %%
#W3A14
a , b = map(float , input().split())
if a == 0 and b != 0:
    print('vo nghiem')
elif a == 0 and b == 0:
    print('vo so nghiem')
else:
    print(f'{-b/a:.2f}')
# Out:
# -2.00

# %%
#W3A15
a = float(input())
if a < 5:
    print("yeu")
elif a >= 5 and a < 6.5:
    print("trung binh")
elif a >= 6.5 and a< 8:
    print("kha")
else: 
    print("gioi")
# Out:
# gioi

# %%
#W3A16
a = float(input())
if a >= (a//1 + 0.5):
    print(int(a//1+1),int(a//1),int(a//1+1))
elif a < (a//1 + 0.5):
    print(int(a//1 +1),int(a//1),int(a//1))
# Out:
# 3 2 3

# %%
#W3A17
a , b , c , d = map(int, input().split())
if c * b/a == d and (b/a)//1 == b/a :
    print("yes")
else: 
    print("no")
# Out:
# yes
