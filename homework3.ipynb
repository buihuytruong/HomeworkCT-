# %% [markdown]
# Bai 1

# %%
for i in range(100):
    if i%2 != 0:
        print(i)

# %% [markdown]
# Bai 2

# %%
for i in range(1,100):
    if i%3 == 0 and i%3 == 0:
        print(i)

# %% [markdown]
# Bai 3

# %%
a = int(input())
if a > 0:
    for i in range (1,11):
        print(a,"x",i,"=",a*i )

# %% [markdown]
# Bai 4

# %%
h = int(input())
for i in range (1,h+1):
    a =' ' * (h-i)
    if i == 1:
        print(a + '*')
    elif i == h:
        print('*'*(2*h-1))
    else:
        b = '*' + (' '*(2*i-3))
        print(a + b + '*')

# %% [markdown]
# Bai 5

# %%
n = int(input())
s = 0
for i in range(n+1):
    s += i
print(s)

# %% [markdown]
# Bai 6

# %%
a = int(input())
b =[]
for i in range (1,a+1):
    if a % i == 0:
        b.append(i)
print(*b)
# Out:
# 1 2 5 10

# %% [markdown]
# Bai 7

# %%
a = -1
while a < 0:
    a = int(input())
    if a < 0:
        print("nhap lai")

count = 0

for i in range(1,a+1):
    if a%i == 0:
        count += 1
print(count)
# Out:
# 0

# %% [markdown]
# Bai 8

# %%
def uc(a,b):
    x =[]
    for i in range(1,a+1):
        if a%i == 0 and b%i == 0:
            x.append(i)
    return print(*x)
a , b =map(int , input().split())
uc(a,b)
# Out:
# 1 2 5 10

# %% [markdown]
# Bai 9

# %%
while True:
    a = int(input())
    if a < 0:
        print("nhap lai")
    else:
        break
if a**0.5 //1 == a**0.5:
    print("yes")
else:
    print("nuh")
# Out:
# nuh

# %% [markdown]
# Bai 10

# %%
a = -1 
while a<0:
    a = int(input())
    if a <0:
        print("nhap lai")
def uoc(x):
    s = 0
    for i in range (1,x):
        if x%i == 0:
            s += i
    return 
if uoc(a) == a:
    print("yes")
else:
    print("no")
# Out:
# nhap lai
# no

# %% [markdown]
# Bai 11

# %%
a = -1 
while a<=0:
    a = int(input())
    if a <=0:
        print("nhap lai")

print("ban nhap dung r")
# Out:
# nhap lai
# nhap lai
# ban nhap dung r

# %% [markdown]
# Bai 12

# %%
n = int(input())
s = 0
k = 1
while s < n:
    if s < n:
        k += 1
        s += k
    else:
        break
print(s-k,k-1)
# Out:
# 14 5

# %% [markdown]
# Bai 13

# %%
a = int(input())
s = 1
k = 1
while s < a:
    if s < a:
        k +=1
        s += 1/k
    else:
        break
print(s,k)
# Out:
# 10.000043008275778 12367
# 10.000043008275778 12367

# %% [markdown]
# Bai 14

# %%
a = int(input())
s = 1
k = 1
while s < a:
    if s < a:
        k +=1
        s += 1/k
    else:
        break
print(s,k)
# Out:
# 10.000043008275778 12367

# %% [markdown]
# Bai 15

# %%
a = int(input())
b = str(a)
print(len(b))
# Out:
# 2

# %% [markdown]
# Bai 16

# %%
n = int(input())
x = str(n)
y = []
a = 0
b = 0
for i in x:
    y.append(i)
for k in y:
    if int(k) % 2 == 0:
        a += 1 
    else:
        b += 1
print(a,b)
# Out:
# 3 1

# %% [markdown]
# Bai 17

# %%
n = int(input())
x = str(n)
y = []
a = 0
for i in x:
    y.append(i)
for k in y:
    a += int(k)
print(a)
# Out:
# 5

# %% [markdown]
# Bai 18

# %%
n = int(input())
if n<=0:
    print("nuh")
else:
    while n % 3 == 0:
        n //= 3 
    if n == 1 :
        print('yes')
    else:
        print("no")
# Out:
# no

# %% [markdown]
# Bai 19

# %%
#an = an-1 + an-2
n =int(input())
a , b = 0, 1
s = 0
while s < n:
    s = a + b
    a , b = b , s
    if s > n:
        break
print(s -(s-a))
# Out:
# 8

# %% [markdown]
# Bai 20

# %%
a = int(input())
def snt(a):
    x = [1,2,3,5,7]
    count = 0
    a = str(a)
    for i in a:
        if int(i) in x:
            count +=1
    return count
print(snt(a))
# Out:
# 1
